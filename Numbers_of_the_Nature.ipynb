# %%
import numpy as np

# -----------------------------
# Fundamental constants
# -----------------------------
hbar = 6.582119569e-16     # eV*s
c = 2.99792458e10          # cm/s
epsilon0n = 55.26349406e4  # e/(V cm)
kB = 8.617333262e-5        # eV/K
ec = 1.60217663e-19        # e → Coulumb
J = 1.60218e-19            # eV → J

dGraphene = 3.4e-10        # m, Graphene interlayer spacing
vfG = 1e6                  # m/s, electron velocity in Graphene
a = 1e-9  # meters

mu0 = 1 / (c**2 * epsilon0n)
muB = 1e4 * 5.7883818060e-5   # e*cm^2/sec

tau = 0.5e-12              # s
Gamma = hbar / tau         # eV

alpha = 1/137

print("e^2/(hbar*c*eps_0) =", 1 / (hbar * c * epsilon0n))
print("v =", (hbar * vfG / a))
# Out:
# e^2/(hbar*c*eps_0) = 0.09170123610074787
# v = 0.6582119569
